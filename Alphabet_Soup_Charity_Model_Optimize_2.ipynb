# %% [markdown]
# <a href="https://colab.research.google.com/github/damiencrim/deep_learning_challenge/blob/main/Alphabet_Soup_Charity_Model_Optimize_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN'.
application_df.drop(columns=["EIN"],inplace=True)

# %%
application_df.head()
# Out:
#                                        NAME APPLICATION_TYPE  \
# 0              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# ...

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# NAME                      19568
# APPLICATION_TYPE             17
# AFFILIATION                   6
# CLASSIFICATION               71
# USE_CASE                      5
# ORGANIZATION                  4
# STATUS                        2
# INCOME_AMT                    9
# SPECIAL_CONSIDERATIONS        2
# ASK_AMT                    8747
# IS_SUCCESSFUL                 2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
app_count = application_df.APPLICATION_TYPE.value_counts()
app_count
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
applications_type_to_replace = list(app_count[app_count <500].index)

# Replace in dataframe
for app in applications_type_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification_count = application_df.CLASSIFICATION.value_counts()
classification_count
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification_count_to_replace = list(classification_count[classification_count<1000].index)

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
print(classification_count >1)
# Out:
# C1000     True
# C2000     True
# C1200     True
# C3000     True
# C2100     True
#          ...
# C4120    False
# C8210    False
# C2561    False
# C4500    False
# C2150    False
# Name: CLASSIFICATION, Length: 71, dtype: bool

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classification_count_to_replace = list(classification_count[classification_count<1000].index)

# Replace in dataframe
for cls in classification_count_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
application_df.head()
# Out:
#                                        NAME APPLICATION_TYPE  \
# 0              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# ...

# %%
# Choose NAME value counts for binning
name_count = application_df['NAME'].value_counts()
name_count
# Out:
# PARENT BOOSTER USA INC                                                  1260
# TOPS CLUB INC                                                            765
# UNITED STATES BOWLING CONGRESS INC                                       700
# WASHINGTON STATE UNIVERSITY                                              492
# AMATEUR ATHLETIC UNION OF THE UNITED STATES INC                          408
#                                                                         ...
# ST LOUIS SLAM WOMENS FOOTBALL                                              1
# AIESEC ALUMNI IBEROAMERICA CORP                                            1
# WEALLBLEEDRED ORG INC                                                      1
# AMERICAN SOCIETY FOR STANDARDS IN MEDIUMSHIP & PSYCHICAL INVESTIGATI       1
# WATERHOUSE CHARITABLE TR                                                   1
# Name: NAME, Length: 19568, dtype: int64

# %%
# Choose a cutoff value and create a list of names to be replaced
names_to_replace = list(name_count[name_count< 100].index)

# Replace in dataframe
for name in names_to_replace:
    application_df['NAME'] = application_df['NAME'].replace(
        name, "Other")

# Check to make sure binning was successful
application_df['NAME'].value_counts()
# Out:
# Other                                                                 25987
# PARENT BOOSTER USA INC                                                 1260
# TOPS CLUB INC                                                           765
# UNITED STATES BOWLING CONGRESS INC                                      700
# WASHINGTON STATE UNIVERSITY                                             492
# AMATEUR ATHLETIC UNION OF THE UNITED STATES INC                         408
# PTA TEXAS CONGRESS                                                      368
# SOROPTIMIST INTERNATIONAL OF THE AMERICAS INC                           331
# ALPHA PHI SIGMA                                                         313
# TOASTMASTERS INTERNATIONAL                                              293
# MOST WORSHIPFUL STRINGER FREE AND ACCEPTED MASONS                       287
# LITTLE LEAGUE BASEBALL INC                                              277
# ...

# %%
# Convert categorical data to numeric with `pd.get_dummies`
app_dummied = pd.get_dummies(application_df)
app_dummied.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  NAME_ALPHA PHI SIGMA  \
# 0       1     5000              1                     0
# 1       1   108590              1                     0
# 2       1     5000              0                     0
# 3       1     6692              1                     0
# 4       1   142590              1                     0
#
#    NAME_AMATEUR ATHLETIC UNION OF THE UNITED STATES INC  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    NAME_AMERICAN ASSOCIATION OF UNIVERSITY WOMEN  NAME_CIVITAN INTERNATIONAL  \
# 0                                              0                           0
# 1                                              0                           0
# ...

# %%
app_dummied.drop("IS_SUCCESSFUL",1)
# Out:
# <ipython-input-15-a75712dcd952>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   app_dummied.drop("IS_SUCCESSFUL",1)
#        STATUS   ASK_AMT  NAME_ALPHA PHI SIGMA  \
# 0           1      5000                     0
# 1           1    108590                     0
# 2           1      5000                     0
# 3           1      6692                     0
# 4           1    142590                     0
# ...       ...       ...                   ...
# 34294       1      5000                     0
# 34295       1      5000                     0
# 34296       1      5000                     0
# 34297       1      5000                     0
# 34298       1  36500179                     0
#
#        NAME_AMATEUR ATHLETIC UNION OF THE UNITED STATES INC  \
# 0                                                      0
# 1                                                      0
# ...

# %%
# Split our preprocessed data into our features and target arrays
X = app_dummied.drop("IS_SUCCESSFUL", axis=1)
y = app_dummied.IS_SUCCESSFUL

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
X_train.head()
# Out:
#        STATUS   ASK_AMT  NAME_ALPHA PHI SIGMA  \
# 30531       1      5000                     0
# 22775       1      5000                     0
# 19057       1      5000                     0
# 27536       1      5000                     0
# 21331       1  11121098                     0
#
#        NAME_AMATEUR ATHLETIC UNION OF THE UNITED STATES INC  \
# 30531                                                  0
# 22775                                                  0
# 19057                                                  0
# 27536                                                  0
# 21331                                                  0
#
#        NAME_AMERICAN ASSOCIATION OF UNIVERSITY WOMEN  \
# 30531                                              0
# 22775                                              0
# 19057                                              0
# 27536                                              0
# 21331                                              0
#
# ...

# %%
type(X_train.index)
# Out:
# pandas.core.indexes.numeric.Int64Index

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# !pip install pandas tensorflow

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len( X_train_scaled[0])
hidden_nodes_layer1=7
hidden_nodes_layer2=14
hidden_nodes_layer3=21
hidden_nodes_layer4=21
hidden_nodes_layer5=28

nn = tf.keras.models.Sequential()

nn = tf.keras.models.Sequential()

# %%
# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation='relu'))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation='relu'))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation='tanh'))

# Fourth hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer4, activation='linear'))

# Fifth hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer5, activation='relu'))



# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 7)                 525
#
#  dense_1 (Dense)             (None, 14)                112
#
#  dense_2 (Dense)             (None, 21)                315
#
#  dense_3 (Dense)             (None, 21)                462
#
#  dense_4 (Dense)             (None, 28)                616
#
#  dense_5 (Dense)             (None, 1)                 29
#
# ...
# Total params: 2059 (8.04 KB)
# Trainable params: 2059 (8.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics=['accuracy'])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,validation_split=0.15, epochs=200)
# Out:
# Epoch 1/100
# 684/684 [==============================] - 3s 3ms/step - loss: 0.5450 - accuracy: 0.7181 - val_loss: 0.5112 - val_accuracy: 0.7357
# Epoch 2/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5024 - accuracy: 0.7477 - val_loss: 0.5012 - val_accuracy: 0.7432
# Epoch 3/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.4973 - accuracy: 0.7506 - val_loss: 0.5015 - val_accuracy: 0.7437
# Epoch 4/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.4940 - accuracy: 0.7547 - val_loss: 0.4977 - val_accuracy: 0.7442
# Epoch 5/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.4923 - accuracy: 0.7573 - val_loss: 0.4979 - val_accuracy: 0.7471
# Epoch 6/100
# 684/684 [==============================] - 3s 4ms/step - loss: 0.4912 - accuracy: 0.7594 - val_loss: 0.4980 - val_accuracy: 0.7515
# Epoch 7/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.4956 - accuracy: 0.7515 - 337ms/epoch - 1ms/step
# Loss: 0.4956136643886566, Accuracy: 0.7514868974685669

# %%
from google.colab import files

# Export our model to HDF5 file
nn.save('/content/AlphabetSoupCharityOptimized.h5')
files.download('/content/AlphabetSoupCharityOptimized.h5')
